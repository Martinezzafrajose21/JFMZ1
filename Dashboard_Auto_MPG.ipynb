# %% [markdown]
# # Dashboard Auto MPG - Proyecto final
#
# **José Felipe Martínez Zafra - UCompensar - Septiembre de 2026**
#
# Este notebook inicia el dashboard Dash del proyecto. En Binder, ejecuta todas las celdas; la aplicación se presenta mediante el proxy de JupyterHub.

# %%
# %pip install -q -r requirements.txt

# %%
from app import app
print("Dashboard cargado. Si Binder solicita permisos de visualización, utiliza el modo inline.")

# %%
import os

if os.environ.get('JUPYTERHUB_SERVICE_PREFIX'):
    app.run(jupyter_mode='inline', jupyter_server_url='', debug=False, port=8050)
else:
    app.run(jupyter_mode='inline', debug=False, port=8050)
